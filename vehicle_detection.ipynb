# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/object_yolo_v5/
# Out:
# /content/drive/MyDrive/object_yolo_v5

# %%
! git clone 'https://github.com/ultralytics/yolov5' '/content/drive/MyDrive/object_yolo_v5/yolov5'
# Out:
# fatal: destination path '/content/drive/MyDrive/object_yolo_v5/yolov5' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/object_yolo_v5/yolov5
# Out:
# /content/drive/MyDrive/object_yolo_v5/yolov5

# %%
# !pip install -U  -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.2 MB 8.8 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 7.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 59.5 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 283 kB/s
# ...
#      |████████████████████████████████| 5.8 MB 60.8 MB/s
# ...
#      |████████████████████████████████| 930 kB 41.5 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
# ...

# %%
# !python train.py --img 640 --batch 32 --epochs 400 --cfg yolov5m.yaml --data coco128.yaml --weights "" --nosave --cache
# Out:
# train: weights=, cfg=yolov5m.yaml, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=400, batch_size=32, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 87 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-134-gc9a3b14 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
 # !python detect.py --weights /content/drive/MyDrive/object_yolo_v5/yolov5/runs/train/exp57/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/object_yolo_v5/detection/test/ --save-conf
# Out:
# detect: weights=['/content/drive/MyDrive/object_yolo_v5/yolov5/runs/train/exp57/weights/last.pt'], source=/content/drive/MyDrive/object_yolo_v5/detection/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-134-gc9a3b14 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 20861016 parameters, 0 gradients, 48.0 GFLOPs
# image 1/9 /content/drive/MyDrive/object_yolo_v5/detection/test/11Truck.jpg: 384x640 1 Truck, Done. (0.022s)
# image 2/9 /content/drive/MyDrive/object_yolo_v5/detection/test/12car.jpg: 480x640 3 Cars, Done. (0.023s)
# ...

# %%
import glob
from IPython.display import Image ,display # for displaying images
for imagename in glob.glob('/content/drive/MyDrive/object_yolo_v5/yolov5/runs/detect/exp32/*.jpg'):
    display(Image(filename=imagename))
    print('.................................................')
    print('.................................................')
    print('.................................................')
# Out:
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................

# %%
lis=['/content/drive/MyDrive/object_yolo_v5/yolov5/runs/detect/exp32/BUS_155.jpeg','/content/drive/MyDrive/object_yolo_v5/yolov5/runs/detect/exp32/BUS_156.jpeg','/content/drive/MyDrive/object_yolo_v5/yolov5/runs/detect/exp32/BUS_157.jpeg']
import glob
from IPython.display import Image ,display # for displaying images
for x in lis:
    for imagename in glob.glob(x):
        display(Image(filename=imagename))
        print('.................................................')
        print('.................................................')
        print('.................................................')
# Out:
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................
# .................................................

# %%
# !python detect.py --weights /content/drive/MyDrive/object_yolo_v5/yolov5/runs/train/exp57/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4 --save-conf
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (4187/9184) /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4: 384x640 1 Car, Done. (0.548s)
# video 1/1 (4188/9184) /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4: 384x640 Done. (0.556s)
# video 1/1 (4189/9184) /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4: 384x640 Done. (0.537s)
# video 1/1 (4190/9184) /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4: 384x640 Done. (0.553s)
# video 1/1 (4191/9184) /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4: 384x640 Done. (0.540s)
# video 1/1 (4192/9184) /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4: 384x640 Done. (0.550s)
# video 1/1 (4193/9184) /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4: 384x640 Done. (0.535s)
# video 1/1 (4194/9184) /content/drive/MyDrive/object_yolo_v5/detection/Road_traffic.mp4: 384x640 1 Car, Done. (0.546s)
# ...
